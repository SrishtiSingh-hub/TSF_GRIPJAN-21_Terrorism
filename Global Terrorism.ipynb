# %% [markdown]
# # TSF GRIP JAN'21 TASK-4

# %% [markdown]
# # EXPLORATORY DATA  ANALYSIS - TERRORISM
#
# DATASET LINK- https://bit.ly/2TK5Xn5

# %% [markdown]
# # DISPLAYED BY SRISHTI SINGH

# %% [markdown]
# IMPORT THE NECESSARY LIBRARIES

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("globalterrorismdb_0718dist.csv", encoding='ISO-8859-1')
df.head()
# Out:
# C:\Users\user\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
df.corr()
# Out:
#                  eventid     iyear    imonth      iday  extended   country  \
# eventid         1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear           0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth          0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday            0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended        0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# country        -0.135039 -0.135023 -0.006305  0.003468 -0.020466  1.000000
# region          0.401371  0.401384 -0.002999  0.009710  0.038389  0.148597
# latitude        0.166886  0.166933 -0.015978  0.003423 -0.024749  0.178567
# longitude       0.003907  0.003917 -0.003880 -0.002285  0.000523 -0.000269
# specificity     0.030641  0.030626  0.003621 -0.006991  0.057897 -0.084599
# vicinity        0.070646  0.070659 -0.004501 -0.005367  0.017784 -0.012291
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.rename(columns={'eventid':'Event_Id','iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)
df.head(15)
# Out:
#         Event_Id  Year  Month  Day approxdate  extended resolution  country  \
# 0   197000000001  1970      7    2        NaN         0        NaN       58
# 1   197000000002  1970      0    0        NaN         0        NaN      130
# 2   197001000001  1970      1    0        NaN         0        NaN      160
# 3   197001000002  1970      1    0        NaN         0        NaN       78
# 4   197001000003  1970      1    0        NaN         0        NaN      101
# 5   197001010002  1970      1    1        NaN         0        NaN      217
# 6   197001020001  1970      1    2        NaN         0        NaN      218
# 7   197001020002  1970      1    2        NaN         0        NaN      217
# 8   197001020003  1970      1    2        NaN         0        NaN      217
# 9   197001030001  1970      1    3        NaN         0        NaN      217
# 10  197001050001  1970      1    1        NaN         0        NaN      217
# ...

# %%
df['Calamity'] = df['Killed'] + df['Wounded']
df.head()
# Out:
#        Event_Id  Year  Month  Day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region  ... scite1 scite2 scite3  dbsource  INT_LOG  \
# 0  Dominican Republic       2  ...    NaN    NaN    NaN      PGIS        0
# 1              Mexico       1  ...    NaN    NaN    NaN      PGIS        0
# 2         Philippines       5  ...    NaN    NaN    NaN      PGIS       -9
# 3              Greece       8  ...    NaN    NaN    NaN      PGIS       -9
# 4               Japan       4  ...    NaN    NaN    NaN      PGIS       -9
#
#    INT_IDEO  INT_MISC INT_ANY related  Calamity
# ...

# %%
display(df.isnull().sum().sort_values(ascending=False))
# Out:
# gsubname3           181671
# weapsubtype4_txt    181621
# weapsubtype4        181621
# weaptype4_txt       181618
# weaptype4           181618
# claimmode3_txt      181558
# claimmode3          181558
# gsubname2           181531
# claim3              181373
# guncertain3         181371
# divert              181367
# gname3              181367
# attacktype3_txt     181263
# attacktype3         181263
# ransomnote          181177
# ransompaidus        181139
# ransomamtus         181128
# claimmode2_txt      181075
# claimmode2          181075
# ransompaid          180917
# corp3               180665
# targsubtype3_txt    180594
# targsubtype3        180594
# natlty3             180544
# natlty3_txt         180544
# target3             180516
# targtype3_txt       180515
# targtype3           180515
# ransomamt           180341
# weapsubtype3        179998
#                      ...
# doubtterr                1
# INT_MISC                 0
# country                  0
# ...

# %%
Column = ['Event_Id','Year','Month','Day','Country','Region','AttackType','Target','Killed','Wounded','Summary','Group','Target_type','Weapon_type','Motive']
df_proc = df[~df.Killed.isna()][Column].reset_index(drop=True)
df_proc.head()
# Out:
#        Event_Id  Year  Month  Day             Country  \
# 0  197000000001  1970      7    2  Dominican Republic
# 1  197000000002  1970      0    0              Mexico
# 2  197001000001  1970      1    0         Philippines
# 3  197001010002  1970      1    1       United States
# 4  197001020001  1970      1    2             Uruguay
#
#                         Region                   AttackType  \
# 0  Central America & Caribbean                Assassination
# 1                North America  Hostage Taking (Kidnapping)
# 2               Southeast Asia                Assassination
# 3                North America                Armed Assault
# 4                South America                Assassination
#
#                                               Target  Killed  Wounded  \
# 0                                       Julio Guzman     1.0      0.0
# 1                            Nadine Chaval, daughter     0.0      0.0
# ...

# %% [markdown]
# COUNTRIES THAT HAVE MORE VICTIMS

# %%
df_proc.groupby(['Country'])['Killed'].sum().sort_values(ascending=False).head(7)
# Out:
# Country
# Iraq           78589.0
# Afghanistan    39384.0
# Pakistan       23822.0
# Nigeria        22682.0
# India          19341.0
# Sri Lanka      15530.0
# Syria          15229.0
# Name: Killed, dtype: float64

# %% [markdown]
# COUNTRIES THAT ARE MOSTLY AFFECTED

# %%
sns.barplot(df_proc['Country'].value_counts()[:10].index,df_proc['Country'].value_counts()[:10].values)
plt.xlabel('Countries')
plt.ylabel('Number of attacks')
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# HOT ZONE OF TERRIORSM

# %%
def color_from_int(num,max_value):
    red = num/max_value
    blue = 1.0 - (num/max_value)
    green = 1.0 - (num/max_value)
    return (red, green, blue)

# %%
df_temp = df.groupby(["Country"])["Event_Id"].count().reset_index(name="attack_count").sort_values("attack_count",ascending=False)
display(df_temp.head())
min_val = df_temp.loc[0:15]["attack_count"].min()
max_val = df_temp.loc[0:15]["attack_count"].max()
plt.figure(figsize=(10,10))
plt.title("HOT ZONE OF TERRIORSM")
plt.bar(x=df_temp[0:15]["Country"],height=df_temp[0:15]["attack_count"],align='center',color=df_temp.loc[0:15]["attack_count"].apply(lambda x, max_val=max_val: color_from_int(x,max_val)))
plt.xticks(rotation='vertical')
plt.show()
# Out:
#          Country  attack_count
# 84          Iraq         24636
# 134     Pakistan         14368
# 0    Afghanistan         12731
# 80         India         11960
# 35      Colombia          8306

# %% [markdown]
# Number Of Terrorist Activities Each Year

# %%
print("We have data for years {0} to {1}".format(df["Year"].min(),df["Year"].max()))
df_temp = df.groupby("Year")["Event_Id"].count().reset_index(name="attacks")
max_val = df_temp["attacks"].max()
display(df_temp)
# Out:
# We have data for years 1970 to 2017
#     Year  attacks
# 0   1970      651
# 1   1971      471
# 2   1972      568
# 3   1973      473
# 4   1974      581
# 5   1975      740
# 6   1976      923
# 7   1977     1319
# 8   1978     1526
# 9   1979     2662
# 10  1980     2662
# 11  1981     2586
# 12  1982     2544
# 13  1983     2870
# 14  1984     3495
# 15  1985     2915
# 16  1986     2860
# 17  1987     3183
# 18  1988     3721
# 19  1989     4324
# 20  1990     3887
# 21  1991     4683
# 22  1992     5071
# 23  1994     3456
# 24  1995     3081
# 25  1996     3058
# 26  1997     3197
# 27  1998      934
# 28  1999     1395
# 29  2000     1814
# 30  2001     1906
# 31  2002     1333
# 32  2003     1278
# 33  2004     1166
# 34  2005     2017
# 35  2006     2758
# 36  2007     3242
# 37  2008     4805
# 38  2009     4721
# 39  2010     4826
# 40  2011     5076
# 41  2012     8522
# 42  2013    12036
# 43  2014    16903
# 44  2015    14965
# 45  2016    13587
# 46  2017    10900

# %% [markdown]
# Number Of Terrorist Activities Each Year

# %%
plt.figure(figsize=(10,10))
plt.title("Number Of Terrorist Activities Each Year")
plt.xlabel("Years")
plt.ylabel("Number of attacks")
plt.plot(df_temp["Year"],df_temp["attacks"])
plt.show()

# %% [markdown]
# Attacks Distribution Of Regions By Year

# %%
df_region=pd.crosstab(df.Year,df.Region)
df_region.plot(color=sns.color_palette('Set1',12))
fig=plt.gcf()
fig.set_size_inches(20,15)
plt.show()

# %% [markdown]
# Attack types and regions

# %%
pd.crosstab(df.Region,df.AttackType).plot.barh(stacked=True,width=1,color=sns.color_palette('coolwarm',10))
fig=plt.gcf()
fig.set_size_inches(15,10)
plt.show()

# %% [markdown]
# 5 biggest attacks by killed people

# %%
big_att = df_proc.groupby(['Killed'])['Group','Country','Year','Target_type'].max().sort_values(by='Killed',ascending=False).iloc[0:5]
big_att
# Out:
#                                               Group        Country  Year  \
# Killed
# 1570.0  Islamic State of Iraq and the Levant (ISIL)           Iraq  2014
# 1384.0                                     Al-Qaida  United States  2001
# 1383.0                                     Al-Qaida  United States  2001
# 1180.0                              Hutu extremists         Rwanda  1994
# 953.0   Islamic State of Iraq and the Levant (ISIL)           Iraq  2014
#
#                         Target_type
# Killed
# 1570.0                     Military
# 1384.0  Private Citizens & Property
# 1383.0  Private Citizens & Property
# 1180.0  Private Citizens & Property
# 953.0   Private Citizens & Property
